# %% [markdown]
# # Prediction

# %%
try:
    import google.colab
    googleColab = True
except:
    googleColab = False

print(f"In google colab: {googleColab}")
# Out:
# In google colab: False

# %%
import numpy as np
import pandas as pd
import subprocess, time
from datasets import Dataset, DatasetDict
import os

# %%
import torch

device = torch.device("cpu")
if torch.cuda.is_available():
    running = subprocess.run(["nvidia-smi"], stdout=subprocess.PIPE).stdout.decode("utf-8")
    device = torch.device("cuda:0")
    print(running)
else:
    print("False")
# Out:
# False

# %%
rootPath = os.getcwd()

if not googleColab:
    rootPath = os.path.dirname(rootPath)

modelsPath = os.path.join(rootPath, "models")
dataPath = os.path.join(rootPath, "data")

print(f"Data path: {dataPath}\n\nModels path: {modelsPath}")
# Out:
# Data path: c:\Users\CND1183F38\Documents\Github\ML-FastAPI-Docker\data
#
# Models path: c:\Users\CND1183F38\Documents\Github\ML-FastAPI-Docker\models

# %%
nameFile = "Language Detection.csv"
datasetPath = os.path.join(dataPath, nameFile)

# %%
import pandas as pd

colnames = ["text", "label"]
df_test = pd.read_csv(datasetPath, header=0, names=colnames)
df_test = df_test.sample(n=30, random_state=1)
df_test
# Out:
#                                                    text       label
# 7413  Data una codifica della (nota) conoscenza di b...     Italian
# 3931  alors la prochaine fois que vous entendrez par...      French
# 4195                      bravo je l'apprécie vraiment.      French
# 2048  [9][10][11][12] மேலும், இது அலெக்சா இணையத்தளத்...       Tamil
# 6945  prøv at kopiere min udtale nøjagtigt inklusive...      Danish
# 2580  Edições em diferentes idiomas, cada uma sob co...  Portugeese
# 7770  quando ha starnutito oh oh e l'ultima fermata ...     Italian
# 2680  Usuários não registrados são, em algum sentido...  Portugeese
# 5382  No puedo creerlo, tienes que estar bromeando p...     Spanish
# 7311  Facendo riferimento alla Legge di Linus sullo ...     Italian
# 9398                                 اعتذر على مقاطعتك.      Arabic
# 3473  Cet événement donne lieu à de nombreux article...      French
# 7284  Alcuni organi d'informazione hanno citato le v...     Italian
# 4659                         wat is uw mening hierover?       Dutch
# 5213  Ya en los primeros días de la IA como discipli...     Spanish
# 8697                    du kan bara säga inga bekymmer.    Sweedish
# 6767  penge, men du ville ikke få det banklån, medmi...      Danish
# 3028                            oh, isso é quase louco.  Portugeese
# 589   [246] Edits falsely identified by bots as the ...     English
# 1315                                  thanks a million.     English
# 4071                                je vais le prendre.      French
# 2065  விக்கிப்பீடியாவிற்கு முன்னதான வேறு சில இணையத்த...       Tamil
# 3842  Arthur Samuel, informaticien américain pionnie...      French
# 4948  Al contrario de lo que sucede con muchas otras...     Spanish
# 8315  269 språkversioner hade i september 2020 över ...    Sweedish
# 8479  Enligt Sanger främställs därför minoritetsuppf...    Sweedish
# 2942  ou os negócios estão fracos neste trimestre, v...  Portugeese
# 1961  മാണിക്യത്തിന്റെ സലാഡുകളും അതിനു മുകളിലുള്ള റൊട...   Malayalam
# 9407                                 لا ، لا أعتقد ذلك.      Arabic
# 218   [78] Nature and wildness have been important s...     English

# %%
from tqdm.notebook import tqdm
import os

name_model = "finetuning-binary-language-classifier"
output_dir = os.path.join(modelsPath, name_model)

# %%
from transformers import BertTokenizer
from transformers import BertForSequenceClassification

tokenizer = BertTokenizer.from_pretrained(output_dir)
model = BertForSequenceClassification.from_pretrained(output_dir)

# %%
print(f"Model max length: {tokenizer.model_max_length}\nModel num labels: {model.num_labels}")
# Out:
# Model max length: 512
# Model num labels: 2

# %%
from transformers import pipeline
pipe = pipeline(task="text-classification", model=model, tokenizer=tokenizer, device=device)

# %%
dataForPrediction = Dataset.from_dict(df_test)["text"] # it is preferred Dataset obj, as in this way

# %%
tokenizer_kwargs = {
    #"padding":True,
    "truncation": True,
    "max_length": tokenizer.model_max_length, # if you want you can change, maybe
    "top_k": 1,
    "batch_size": 256,
    #return_tensors" : "pt"
}

#prediction = pipe(test_df["text"].to_list(), **tokenizer_kwargs)
prediction = []
for out in tqdm(pipe(dataForPrediction, **tokenizer_kwargs), total=len(dataForPrediction)):
    prediction.append(out)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
mapTarget = {
    0 : "Non italiano",
    1 : "Italiano"
}

def mapTargetFun(row):
    return mapTarget[row]

df_test.loc[ df_test["label"] == "Italian", "target"] = 1
df_test.loc[ df_test["label"] != "Italian", "target"] = 0
df_test["target"] = df_test["target"].astype(int)
df_test["target"] = df_test["target"].apply(mapTargetFun)

# %%
mapTarget = {
    "LABEL_0" : "Non italiano",
    "LABEL_1" : "Italiano"
}

df_test["prediction"] = [mapTarget[pred[0]["label"]] for pred in prediction]
df_test["score"] = [pred[0]["score"] for pred in prediction]
df_test
# Out:
#                                                    text       label  \
# 7413  Data una codifica della (nota) conoscenza di b...     Italian
# 3931  alors la prochaine fois que vous entendrez par...      French
# 4195                      bravo je l'apprécie vraiment.      French
# 2048  [9][10][11][12] மேலும், இது அலெக்சா இணையத்தளத்...       Tamil
# 6945  prøv at kopiere min udtale nøjagtigt inklusive...      Danish
# 2580  Edições em diferentes idiomas, cada uma sob co...  Portugeese
# 7770  quando ha starnutito oh oh e l'ultima fermata ...     Italian
# 2680  Usuários não registrados são, em algum sentido...  Portugeese
# 5382  No puedo creerlo, tienes que estar bromeando p...     Spanish
# 7311  Facendo riferimento alla Legge di Linus sullo ...     Italian
# 9398                                 اعتذر على مقاطعتك.      Arabic
# 3473  Cet événement donne lieu à de nombreux article...      French
# 7284  Alcuni organi d'informazione hanno citato le v...     Italian
# 4659                         wat is uw mening hierover?       Dutch
# 5213  Ya en los primeros días de la IA como discipli...     Spanish
# 8697                    du kan bara säga inga bekymmer.    Sweedish
# 6767  penge, men du ville ikke få det banklån, medmi...      Danish
# 3028                            oh, isso é quase louco.  Portugeese
# 589   [246] Edits falsely identified by bots as the ...     English
# 1315                                  thanks a million.     English
# 4071                                je vais le prendre.      French
# 2065  விக்கிப்பீடியாவிற்கு முன்னதான வேறு சில இணையத்த...       Tamil
# 3842  Arthur Samuel, informaticien américain pionnie...      French
# 4948  Al contrario de lo que sucede con muchas otras...     Spanish
# 8315  269 språkversioner hade i september 2020 över ...    Sweedish
# 8479  Enligt Sanger främställs därför minoritetsuppf...    Sweedish
# 2942  ou os negócios estão fracos neste trimestre, v...  Portugeese
# 1961  മാണിക്യത്തിന്റെ സലാഡുകളും അതിനു മുകളിലുള്ള റൊട...   Malayalam
# 9407                                 لا ، لا أعتقد ذلك.      Arabic
# 218   [78] Nature and wildness have been important s...     English
#
#             target    prediction     score
# 7413      Italiano      Italiano  0.999783
# 3931  Non italiano  Non italiano  0.999943
# 4195  Non italiano  Non italiano  0.999929
# 2048  Non italiano  Non italiano  0.999939
# 6945  Non italiano  Non italiano  0.999943
# 2580  Non italiano  Non italiano  0.999944
# 7770      Italiano      Italiano  0.999818
# 2680  Non italiano  Non italiano  0.999942
# 5382  Non italiano  Non italiano  0.999946
# 7311      Italiano      Italiano  0.999785
# 9398  Non italiano  Non italiano  0.999951
# 3473  Non italiano  Non italiano  0.999946
# 7284      Italiano      Italiano  0.999778
# 4659  Non italiano  Non italiano  0.999938
# 5213  Non italiano  Non italiano  0.999948
# 8697  Non italiano  Non italiano  0.999938
# 6767  Non italiano  Non italiano  0.999951
# 3028  Non italiano  Non italiano  0.999882
# 589   Non italiano  Non italiano  0.999928
# 1315  Non italiano  Non italiano  0.999703
# 4071  Non italiano  Non italiano  0.999925
# 2065  Non italiano  Non italiano  0.999951
# 3842  Non italiano  Non italiano  0.999947
# 4948  Non italiano  Non italiano  0.999944
# 8315  Non italiano  Non italiano  0.999941
# 8479  Non italiano  Non italiano  0.999944
# 2942  Non italiano  Non italiano  0.999946
# 1961  Non italiano  Non italiano  0.999951
# 9407  Non italiano  Non italiano  0.999954
# 218   Non italiano  Non italiano  0.999911
